# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.4.2)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\lenovo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\lenovo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\lenovo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\lenovo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\lenovo\OneDrive\Desktop\sales eda\SuperStore_Sales_Dataset.csv")
df
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                 4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                 3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                 8604  US-2019-116365  03-01-2019  08-01-2019
# ...                ...             ...         ...         ...
# 5896               907  CA-2020-143259  30-12-2020  03-01-2021
# 5897              1297  CA-2020-115427  30-12-2020  03-01-2021
# 5898              5092  CA-2020-156720  30-12-2020  03-01-2021
# 5899               909  CA-2020-143259  30-12-2020  03-01-2021
# 5900              5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 1     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 2     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# 3        First Class    LR-16915       Lena Radford   Consumer  United States
# 4     Standard Class    CA-12310  Christine Abelman  Corporate  United States
# ...              ...         ...                ...        ...            ...
# 5896  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5897  Standard Class    EB-13975         Erica Bern  Corporate  United States
# 5898  Standard Class    JM-15580      Jill Matthias   Consumer  United States
# 5899  Standard Class    PO-18865  Patrick O'Donnell   Consumer  United States
# 5900  Standard Class    JM-15580      Jill Matthias   Consumer  United States
#
#                City  ...         Category Sub-Category  \
# 0      Gaithersburg  ...        Furniture    Bookcases
# 1      Gaithersburg  ...        Furniture    Bookcases
# 2      Gaithersburg  ...       Technology       Phones
# 3       Los Angeles  ...  Office Supplies      Storage
# 4       San Antonio  ...       Technology  Accessories
# ...             ...  ...              ...          ...
# 5896  New York City  ...        Furniture    Bookcases
# 5897      Fairfield  ...  Office Supplies      Binders
# 5898       Loveland  ...  Office Supplies    Fasteners
# 5899  New York City  ...  Office Supplies      Binders
# 5900       Loveland  ...  Office Supplies    Fasteners
#
#                                            Product Name     Sales Quantity  \
# 0     Bush Westfield Collection Bookcases, Medium Ch...    73.940        1
# 1     Bush Westfield Collection Bookcases, Medium Ch...   173.940        3
# 2                                           GE 30522EE2   231.980        2
# 3     Recycled Steel Personal File for Hanging File ...   114.460        2
# 4                   Imation Clip USB flash drive - 8 GB    30.080        2
# ...                                                 ...       ...      ...
# 5896  Bush Westfield Collection Bookcases, Fully Ass...   213.136        4
# 5897    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl   295.904        2
# 5898                                Bagged Rubber Bands   388.024        3
# 5899               Wilson Jones Legal Size Ring Binders   462.776        3
# 5900                                Bagged Rubber Bands  2975.510        3
#
#        Profit  Returns  Payment Mode  ind1  ind2
# 0     28.2668      NaN        Online   NaN   NaN
# 1     38.2668      NaN        Online   NaN   NaN
# 2     67.2742      NaN         Cards   NaN   NaN
# 3     28.6150      NaN        Online   NaN   NaN
# 4     -5.2640      NaN        Online   NaN   NaN
# ...       ...      ...           ...   ...   ...
# 5896  12.1176      NaN           COD   NaN   NaN
# 5897   4.5188      1.0        Online   NaN   NaN
# 5898  -0.6048      NaN        Online   NaN   NaN
# 5899  19.7910      NaN           COD   NaN   NaN
# 5900  -0.6048      NaN           COD   NaN   NaN
#
# [5901 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   str
#  2   Order Date        5901 non-null   str
#  3   Ship Date         5901 non-null   str
#  4   Ship Mode         5901 non-null   str
#  5   Customer ID       5901 non-null   str
#  6   Customer Name     5901 non-null   str
#  7   Segment           5901 non-null   str
#  8   Country           5901 non-null   str
#  9   City              5901 non-null   str
#  10  State             5901 non-null   str
#  11  Region            5901 non-null   str
#  12  Product ID        5901 non-null   str
#  13  Category          5901 non-null   str
#  14  Sub-Category      5901 non-null   str
#  15  Product Name      5901 non-null   str
#  16  Sales             5901 non-null   float64
#  17  Quantity          5901 non-null   int64
#  18  Profit            5901 non-null   float64
#  19  Returns           287 non-null    float64
#  20  Payment Mode      5901 non-null   str
#  21  ind1              0 non-null      float64
#  22  ind2              0 non-null      float64
# dtypes: float64(5), int64(2), str(16)
# memory usage: 1.0 MB

# %%
df.head()
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 2              4920  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 3              3074  CA-2019-125206  03-01-2019  05-01-2019     First Class
# 4              8604  US-2019-116365  03-01-2019  08-01-2019  Standard Class
#
#   Customer ID      Customer Name    Segment        Country          City  ...  \
# 0    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 1    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 2    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg  ...
# 3    LR-16915       Lena Radford   Consumer  United States   Los Angeles  ...
# 4    CA-12310  Christine Abelman  Corporate  United States   San Antonio  ...
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture    Bookcases
# 2       Technology       Phones
# 3  Office Supplies      Storage
# 4       Technology  Accessories
#
#                                         Product Name   Sales Quantity  \
# 0  Bush Westfield Collection Bookcases, Medium Ch...   73.94        1
# 1  Bush Westfield Collection Bookcases, Medium Ch...  173.94        3
# 2                                        GE 30522EE2  231.98        2
# 3  Recycled Steel Personal File for Hanging File ...  114.46        2
# 4                Imation Clip USB flash drive - 8 GB   30.08        2
#
#     Profit  Returns  Payment Mode  ind1  ind2
# 0  28.2668      NaN        Online   NaN   NaN
# 1  38.2668      NaN        Online   NaN   NaN
# 2  67.2742      NaN         Cards   NaN   NaN
# 3  28.6150      NaN        Online   NaN   NaN
# 4  -5.2640      NaN        Online   NaN   NaN
#
# [5 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# ind1                5901
# ind2                5901
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Row ID+O6G3A1:R6      0.000000
# Order ID              0.000000
# Order Date            0.000000
# Ship Date             0.000000
# Ship Mode             0.000000
# Customer ID           0.000000
# Customer Name         0.000000
# Segment               0.000000
# Country               0.000000
# City                  0.000000
# State                 0.000000
# Region                0.000000
# Product ID            0.000000
# Category              0.000000
# Sub-Category          0.000000
# Product Name          0.000000
# Sales                 0.000000
# Quantity              0.000000
# Profit                0.000000
# Returns              95.136418
# Payment Mode          0.000000
# ind1                100.000000
# ind2                100.000000
# dtype: float64

# %%
df['Order Date'].head()
# Out:
# 0    01-01-2019
# 1    02-01-2019
# 2    02-01-2019
# 3    03-01-2019
# 4    03-01-2019
# Name: Order Date, dtype: str

# %%
pd.pivot_table(df, values='Sales', index='Category', columns='Region', aggfunc='sum')
# Out:
# Region               Central        East      South        West
# Category
# Furniture        105505.4532  117071.973  72984.867  155946.352
# Office Supplies  150154.3530  189066.821  99652.140  204834.373
# Technology        85347.7180  144095.872  79484.074  161660.327

# %%
print(df.columns.tolist())
# Out:
# ['Row ID+O6G3A1:R6', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Profit', 'Returns', 'Payment Mode']

# %%
df.columns = df.columns.str.strip()

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], errors='coerce')

# %%
if 'Returns' in df.columns:
    df['Returns'] = df['Returns'].fillna(0)

# %%
print(df.isnull().sum())
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date          3491
# Ship Date           3550
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns                0
# Payment Mode           0
# dtype: int64

# %%
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Day'] = df['Order Date'].dt.day

# %%
df['HighSales'] = df['Sales'].apply(lambda x: 'Yes' if x > 1000 else 'No')
df[['Sales','HighSales']].head(10)
# Out:
#       Sales HighSales
# 0    73.940        No
# 1   173.940        No
# 2   231.980        No
# 3   114.460        No
# 4    30.080        No
# 5   165.600        No
# 6   180.960        No
# 7  1592.850       Yes
# 8    11.880        No
# 9   959.968        No

# %%
df['ShippingDays'] = (df['Ship Date'] - df['Order Date']).dt.days
df[['Order Date','Ship Date','ShippingDays']].head(10)
# Out:
#   Order Date  Ship Date  ShippingDays
# 0 2019-01-01 2019-07-01         181.0
# 1 2019-02-01 2019-07-01         150.0
# 2 2019-02-01 2019-07-01         150.0
# 3 2019-03-01 2019-05-01          61.0
# 4 2019-03-01 2019-08-01         153.0
# 5 2019-03-01 2019-08-01         153.0
# 6 2019-03-01 2019-08-01         153.0
# 7 2019-03-01 2019-08-01         153.0
# 8 2019-03-01 2019-08-01         153.0
# 9 2019-04-01 2019-09-01         153.0

# %%
df['ProfitMargin'] = (df['Profit'] / df['Sales']) * 100
df[['ProfitMargin','Sales','Profit']].head()
# Out:
#    ProfitMargin   Sales   Profit
# 0     38.229375   73.94  28.2668
# 1     22.000000  173.94  38.2668
# 2     29.000000  231.98  67.2742
# 3     25.000000  114.46  28.6150
# 4    -17.500000   30.08  -5.2640

# %%
df['OrderSize'] = df['Quantity'].apply(
    lambda x: 'Small' if x <= 2 else ('Medium' if x <= 5 else 'Large')
)
df[['OrderSize','Quantity']].head(10)
# Out:
#   OrderSize  Quantity
# 0     Small         1
# 1    Medium         3
# 2     Small         2
# 3     Small         2
# 4     Small         2
# 5    Medium         3
# 6    Medium         5
# 7     Large         7
# 8     Small         2
# 9    Medium         4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax=sns.countplot(x='Category',data=df,color='red')
ax.bar_label(ax.containers[0])
plt.title("Number Of order per Category")
plt.show()

# %% [markdown]
# 1)Office Supplies (3569) has the highest orders → dominates demand.
#
#
# 2)Furniture (1249) and Technology (1083) have much lower orders.
#
#
# 3)Office Supplies is about 3× higher than other categories.
#
#
# 4)Indicates frequent purchases (daily-use items).
#
#
# 5)Furniture & Technology are less frequent, high-value purchases.

# %%
ax=sns.countplot(x='Region',data=df,color="green")
ax.bar_label(ax.containers[0])
plt.title("Number of Order By region")
plt.show()

# %% [markdown]
# 1)West (1901) is the top-performing region, followed by East (1688), while Central (1381) shows moderate demand and South (931) has the lowest orders.
#
#
# 2)There is a significant gap, with West having nearly 2× orders of South, indicating uneven demand distribution.
#
#
# 3)West and East together drive the majority of sales, making them key regions for business performance.
#
#
# 4)South is the weakest region, requiring focused improvement strategies.
#
#
# 5)Overall, there is a strong opportunity to boost low-performing regions and balance growth across all areas.

# %%
ax=sns.countplot(x='Segment',data=df,color="yellow")
ax.bar_label(ax.containers[0])
plt.title("Number of Order By Segment")
plt.show()

# %% [markdown]
# Consumer segment has the highest orders (2997) → top-performing segment
#
#
# Corporate segment (1774) shows moderate performance
# Home Office segment (1130) has the lowest demand
#
#
# Consumer orders are ~2.6× higher than Home Office → large gap
#
#
# Overall, Consumer drives most sales while Home Office needs improvement

# %%
ax=sns.barplot(x='Category',y="Sales",data=df,color="Darkblue")
plt.title("Average sales By Category")
plt.show()

# %%
ax=sns.countplot(x="Category",hue="Region",data=df)
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[2])
ax.bar_label(ax.containers[3])
plt.title("Category Distribution by Region")
plt.show()

# %%
ax=sns.countplot(x="Region",hue="Segment",data=df,palette=['red','blue','orange'])
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
ax.bar_label(ax.containers[2])
plt.title("Region-Wise Customer Segments")
plt.show()

# %%
counts=df['Category'].value_counts()
plt.pie(counts,labels=counts.index,autopct='%1.1f%%',colors=["salmon",'purple','yellow'])
plt.title("Category distribution")
plt.show()

# %%
sns.kdeplot(data=df, x='Sales', hue='Region', fill=True,palette='dark')
plt.title("Sales Distribution by Region")
plt.show()

# %%
corr = df[['Sales','Profit','Quantity']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Sales and profit have a moderate positive correlation (0.33), meaning profit tends to increase with sales but not strongly.
#
#
# Sales and quantity show a weak positive correlation (0.20), indicating higher quantity does not strongly impact total sales.
#
#
# Profit and quantity have a very weak correlation (0.075), suggesting quantity sold has minimal effect on profit.
#
#
# Overall, no strong correlations exist among the variables, indicating weak linear relationships.
#
#
# Profit is likely influenced more by pricing, costs, or discounts rather than just sales volume or quantity.
